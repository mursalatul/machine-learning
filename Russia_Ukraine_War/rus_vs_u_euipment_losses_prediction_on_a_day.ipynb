# %%
import pandas as pd

# %%
df1=pd.read_csv('russia_losses_equipment.csv')
df1.head()
# Out:
#          date  day  aircraft  helicopter  tank    APC  field artillery   MRL  \
# 0  2024-06-02  830       357         326  7765  14980            13233  1089
# 1  2024-06-01  829       357         326  7740  14947            13184  1088
# 2  2024-05-31  828       357         326  7728  14935            13140  1088
# 3  2024-05-30  827       357         326  7710  14913            13101  1088
# 4  2024-05-29  826       357         326  7700  14891            13066  1087
#
#    military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# 0            NaN        NaN  10699          27                    821
# 1            NaN        NaN  10617          27                    815
# 2            NaN        NaN  10587          27                    815
# 3            NaN        NaN  10532          27                    815
# 4            NaN        NaN  10510          27                    815
#
#    special equipment  mobile SRBM system greatest losses direction  \
# ...
